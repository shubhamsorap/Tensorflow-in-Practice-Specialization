# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamsorap/Tensorflow-in-Practice-Specialization/blob/master/CW%5C1st_task_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  from google.colab import drive
  drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/kaggle"
# /content/gdrive/My Drive/Kaggle is the path where kaggle.json is present in the Google Drive

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/kaggle
#Check the present working directory using pwd command
# Out:
# /content/gdrive/My Drive/kaggle

# %%
# !kaggle competitions download -c home-credit-default-risk
# Out:
# ...
#  95% 258M/271M [00:02<00:00, 124MB/s]
# 100% 271M/271M [00:02<00:00, 115MB/s]
# HomeCredit_columns_description.csv: Skipping, found more recently modified local copy (use --force to force download)
# ...
#  97% 74.0M/76.3M [00:00<00:00, 70.1MB/s]
# 100% 76.3M/76.3M [00:00<00:00, 82.6MB/s]
# ...
#  86% 49.0M/56.8M [00:00<00:00, 95.6MB/s]
# 100% 56.8M/56.8M [00:00<00:00, 96.7MB/s]
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# ...
#  90% 33.0M/36.8M [00:00<00:00, 102MB/s]
# 100% 36.8M/36.8M [00:00<00:00, 105MB/s]
# ...
#  83% 30.0M/36.1M [00:00<00:00, 46.6MB/s]
# 100% 36.1M/36.1M [00:00<00:00, 61.4MB/s]
# ...
#   0% 0.00/5.81M [00:00<?, ?B/s]
# 100% 5.81M/5.81M [00:00<00:00, 52.7MB/s]
# ...
#  94% 91.0M/96.7M [00:01<00:00, 74.6MB/s]
# 100% 96.7M/96.7M [00:01<00:00, 66.8MB/s]
# ...
#  94% 102M/109M [00:02<00:00, 38.2MB/s]
# 100% 109M/109M [00:02<00:00, 46.1MB/s]

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  bureau.csv.zip
# replace bureau.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#
# Archive:  credit_card_balance.csv.zip
# replace credit_card_balance.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#
# Archive:  bureau_balance.csv.zip
# replace bureau_balance.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#
# Archive:  installments_payments.csv.zip
# replace installments_payments.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#
# Archive:  application_test.csv.zip
# replace application_test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#
# Archive:  POS_CASH_balance.csv.zip
# replace POS_CASH_balance.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#
# Archive:  application_train.csv.zip
# replace application_train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#
# Archive:  previous_application.csv.zip
# replace previous_application.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#
# 8 archives were successfully processed.

# %%
import pandas as pd

# %%
train1 = pd.read_csv("bureau_balance.csv")
train2 = pd.read_csv("installments_payments.csv")
train3 = pd.read_csv("bureau.csv")
train4 = pd.read_csv("credit_card_balance.csv")
train5 = pd.read_csv("application_test.csv")
train6 = pd.read_csv("POS_CASH_balance.csv")
train7 = pd.read_csv("application_train.csv")
train8 = pd.read_csv("previous_application.csv")

# %%
train1.head()
# Out:
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C
# 3       5715448              -3      C
# 4       5715448              -4      C

# %%
train2.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  ...  AMT_INSTALMENT  AMT_PAYMENT
# 0     1054186      161674  ...        6948.360     6948.360
# 1     1330831      151639  ...        1716.525     1716.525
# 2     2085231      193053  ...       25425.000    25425.000
# 3     2452527      199697  ...       24350.130    24350.130
# 4     2714724      167756  ...        2165.040     2160.585
#
# [5 rows x 8 columns]

# %%
train3.head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU  ... DAYS_CREDIT_UPDATE AMT_ANNUITY
# 0      215354       5714462  ...               -131         NaN
# 1      215354       5714463  ...                -20         NaN
# 2      215354       5714464  ...                -16         NaN
# 3      215354       5714465  ...                -16         NaN
# 4      215354       5714466  ...                -21         NaN
#
# [5 rows x 17 columns]

# %%
train4.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  ...  SK_DPD  SK_DPD_DEF
# 0     2562384      378907  ...       0           0
# 1     2582071      363914  ...       0           0
# 2     1740877      371185  ...       0           0
# 3     1389973      337855  ...       0           0
# 4     1891521      126868  ...       0           0
#
# [5 rows x 23 columns]

# %%
train5.head()
# Out:
#    SK_ID_CURR  ... AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100001  ...                        0.0
# 1      100005  ...                        3.0
# 2      100013  ...                        4.0
# 3      100028  ...                        3.0
# 4      100038  ...                        NaN
#
# [5 rows x 121 columns]

# %%
train6.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  ...  SK_DPD  SK_DPD_DEF
# 0     1803195      182943  ...       0           0
# 1     1715348      367990  ...       0           0
# 2     1784872      397406  ...       0           0
# 3     1903291      269225  ...       0           0
# 4     2341044      334279  ...       0           0
#
# [5 rows x 8 columns]

# %%
train7.head()
# Out:
#    SK_ID_CURR  TARGET  ... AMT_REQ_CREDIT_BUREAU_QRT AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100002       1  ...                       0.0                        1.0
# 1      100003       0  ...                       0.0                        0.0
# 2      100004       0  ...                       0.0                        0.0
# 3      100006       0  ...                       NaN                        NaN
# 4      100007       0  ...                       0.0                        0.0
#
# [5 rows x 122 columns]

# %%
train8.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  ... DAYS_TERMINATION  NFLAG_INSURED_ON_APPROVAL
# 0     2030495      271877  ...            -37.0                        0.0
# 1     2802425      108129  ...         365243.0                        1.0
# 2     2523466      122040  ...         365243.0                        1.0
# 3     2819243      176158  ...           -177.0                        1.0
# 4     1784265      202054  ...              NaN                        NaN
#
# [5 rows x 37 columns]

# %%
#Merge1 = pd.merge(train2,train4,on='SK_ID_PREV',how='left')

# %%
#Merge1.head()

# %%
train8.isnull().sum()
# Out:
# SK_ID_PREV                           0
# SK_ID_CURR                           0
# NAME_CONTRACT_TYPE                   0
# AMT_ANNUITY                     372235
# AMT_APPLICATION                      0
# AMT_CREDIT                           1
# AMT_DOWN_PAYMENT                895844
# AMT_GOODS_PRICE                 385515
# WEEKDAY_APPR_PROCESS_START           0
# HOUR_APPR_PROCESS_START              0
# FLAG_LAST_APPL_PER_CONTRACT          0
# NFLAG_LAST_APPL_IN_DAY               0
# RATE_DOWN_PAYMENT               895844
# RATE_INTEREST_PRIMARY          1664263
# RATE_INTEREST_PRIVILEGED       1664263
# NAME_CASH_LOAN_PURPOSE               0
# NAME_CONTRACT_STATUS                 0
# DAYS_DECISION                        0
# NAME_PAYMENT_TYPE                    0
# CODE_REJECT_REASON                   0
# NAME_TYPE_SUITE                 820405
# NAME_CLIENT_TYPE                     0
# NAME_GOODS_CATEGORY                  0
# NAME_PORTFOLIO                       0
# ...

# %%
train8.dtypes
# Out:
# SK_ID_PREV                       int64
# SK_ID_CURR                       int64
# NAME_CONTRACT_TYPE              object
# AMT_ANNUITY                    float64
# AMT_APPLICATION                float64
# AMT_CREDIT                     float64
# AMT_DOWN_PAYMENT               float64
# AMT_GOODS_PRICE                float64
# WEEKDAY_APPR_PROCESS_START      object
# HOUR_APPR_PROCESS_START          int64
# FLAG_LAST_APPL_PER_CONTRACT     object
# NFLAG_LAST_APPL_IN_DAY           int64
# RATE_DOWN_PAYMENT              float64
# RATE_INTEREST_PRIMARY          float64
# RATE_INTEREST_PRIVILEGED       float64
# NAME_CASH_LOAN_PURPOSE          object
# NAME_CONTRACT_STATUS            object
# DAYS_DECISION                    int64
# NAME_PAYMENT_TYPE               object
# CODE_REJECT_REASON              object
# NAME_TYPE_SUITE                 object
# NAME_CLIENT_TYPE                object
# NAME_GOODS_CATEGORY             object
# NAME_PORTFOLIO                  object
# ...

# %%
train8['AMT_ANNUITY'].fillna((train8['AMT_ANNUITY'].mean()),inplace=True)

# %%
train8['AMT_DOWN_PAYMENT'].fillna((train8['AMT_DOWN_PAYMENT'].mean()),inplace=True)

# %%
train8['AMT_GOODS_PRICE'].fillna((train8['AMT_GOODS_PRICE'].mean()),inplace=True)

# %%
train8['RATE_DOWN_PAYMENT'].fillna((train8['RATE_DOWN_PAYMENT'].mean()),inplace=True)

# %%
train8['RATE_INTEREST_PRIMARY'].fillna((train8['RATE_INTEREST_PRIMARY'].mean()),inplace=True)

# %%
train8['RATE_INTEREST_PRIVILEGED'].fillna((train8['RATE_INTEREST_PRIVILEGED'].mean()),inplace=True)

# %%
train8['CNT_PAYMENT'].fillna((train8['CNT_PAYMENT'].mean()),inplace=True)

# %%
train8['DAYS_FIRST_DRAWING'].fillna((train8['DAYS_FIRST_DRAWING'].mean()),inplace=True)

# %%
train8['DAYS_FIRST_DUE'].fillna((train8['DAYS_FIRST_DUE'].mean()),inplace=True)

# %%
train8['DAYS_LAST_DUE_1ST_VERSION'].fillna((train8['DAYS_LAST_DUE_1ST_VERSION'].mean()),inplace=True)

# %%
train8['DAYS_LAST_DUE'].fillna((train8['DAYS_LAST_DUE'].mean()),inplace=True)

# %%
train8['DAYS_TERMINATION'].fillna((train8['DAYS_TERMINATION'].mean()),inplace=True)

# %%
#train8['NFLAG_INSURED_ON_APPROVAL'].fillna((train8['NFLAG_INSURED_ON_APPROVAL'].mean()),inplace=True)

# %%
train8['AMT_CREDIT'].fillna((train8['AMT_CREDIT'].mean()),inplace=True)

# %%
train8.isnull().sum()
# Out:
# SK_ID_PREV                          0
# SK_ID_CURR                          0
# NAME_CONTRACT_TYPE                  0
# AMT_ANNUITY                         0
# AMT_APPLICATION                     0
# AMT_CREDIT                          0
# AMT_DOWN_PAYMENT                    0
# AMT_GOODS_PRICE                     0
# WEEKDAY_APPR_PROCESS_START          0
# HOUR_APPR_PROCESS_START             0
# FLAG_LAST_APPL_PER_CONTRACT         0
# NFLAG_LAST_APPL_IN_DAY              0
# RATE_DOWN_PAYMENT                   0
# RATE_INTEREST_PRIMARY               0
# RATE_INTEREST_PRIVILEGED            0
# NAME_CASH_LOAN_PURPOSE              0
# NAME_CONTRACT_STATUS                0
# DAYS_DECISION                       0
# NAME_PAYMENT_TYPE                   0
# CODE_REJECT_REASON                  0
# NAME_TYPE_SUITE                820405
# NAME_CLIENT_TYPE                    0
# NAME_GOODS_CATEGORY                 0
# NAME_PORTFOLIO                      0
# NAME_PRODUCT_TYPE                   0
# ...

# %%
train8['NAME_TYPE_SUITE'].fillna("Unknown",inplace=True)

# %%
train8['PRODUCT_COMBINATION'].fillna("Unknown",inplace=True)

# %%
train8.shape
# Out:
# (1670214, 37)

# %%
combine = pd.get_dummies(train8)
combine.shape
# Out:
# (1670214, 166)

# %%
combine.head()
# Out:
#    SK_ID_PREV  ...  PRODUCT_COMBINATION_Unknown
# 0     2030495  ...                            0
# 1     2802425  ...                            0
# 2     2523466  ...                            0
# 3     2819243  ...                            0
# 4     1784265  ...                            0
#
# [5 rows x 166 columns]

# %%
X = combine[combine['NFLAG_INSURED_ON_APPROVAL'].isnull()!=True].drop(['SK_ID_PREV','SK_ID_CURR','NFLAG_INSURED_ON_APPROVAL'], axis=1)
y = combine[combine['NFLAG_INSURED_ON_APPROVAL'].isnull()!=True]['NFLAG_INSURED_ON_APPROVAL']

X_test = combine[combine['NFLAG_INSURED_ON_APPROVAL'].isnull()==True].drop(['SK_ID_PREV','SK_ID_CURR','NFLAG_INSURED_ON_APPROVAL'], axis=1)

X.shape, y.shape, X_test.shape
# Out:
# ((997149, 163), (997149,), (673065, 163))

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

clf=RandomForestClassifier(n_estimators=100)

clf.fit(x_train,y_train)

y_pred=clf.predict(x_val)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_val, y_pred))
# Out:
# Accuracy: 0.9221330792759365
